# %%
from skimage import io

# %%
photo = io.imread('VTNWZc.jpg')

# %%
photo.shape
# Out:
# (1600, 2560, 3)

# %%
from matplotlib import pyplot as plt
plt.imshow(photo)

# %%
photo[:,1100:1800] = [255,0,0]
plt.imshow(photo)

# %%
photo.size
# Out:
# 12288000

# %%
photo[1599,1100]
# Out:
# array([255,   0,   0], dtype=uint8)
